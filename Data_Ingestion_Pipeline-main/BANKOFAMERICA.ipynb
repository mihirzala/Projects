# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import sqlalchemy
import mysql.connector
import os
import boto3
from botocore.exceptions import ClientError
from boto3.session import Session

# %%
def fetch_news():
    
    url = "https://www.americanbankingnews.com/feed"
    resp = requests.get(url)
    soup = BeautifulSoup(resp.content, features="xml")
    items = soup.findAll('item')
    news_items = []
    for item in items:
        news_item = {}
        news_item['title'] = item.title.text
        news_item['description'] = item.description.text
        news_item['link'] = item.link.text
        news_item['pubDate'] = item.pubDate.text
        news_item['creator'] = item.creator.text
        news_item['category'] = item.category.text
        news_items.append(news_item)
        time.sleep(0.3)
    return news_items

# %%
# fetch_news()

# %%
new_df = pd.DataFrame(fetch_news())
new_df
# Out:
#                                                  title  \
# 0    Waratah Capital Advisors Ltd. Takes Position i...
# 1    Comerica Bank Has $98.78 Million Stake in Tesl...
# 2    Wealth Advisors of Iowa LLC Sells 1,076 Shares...
# 3    Wealthquest Corp Has $258,000 Stake in iShares...
# 4    Wealthquest Corp Has $9.06 Million Stock Holdi...
# ..                                                 ...
# 245  Wealthquest Corp Cuts Holdings in iShares Core...
# 246  Wealthquest Corp Buys 6,139 Shares of NextEra ...
# 247  Wealthquest Corp Has $337,000 Stake in Oracle ...
# 248  Wealthquest Corp Acquires 48,839 Shares of Inn...
# 249  Wealthquest Corp Trims Holdings in Walgreens B...
#
#                                            description  \
# 0    Waratah Capital Advisors Ltd. purchased a new ...
# 1    Comerica Bank trimmed its stake in shares of T...
# 2    Wealth Advisors of Iowa LLC cut its stake in s...
# 3    Wealthquest Corp trimmed its position in share...
# 4    Wealthquest Corp raised its holdings in Vangua...
# ..                                                 ...
# 245  Wealthquest Corp decreased its position in iSh...
# 246  Wealthquest Corp boosted its stake in shares o...
# 247  Wealthquest Corp decreased its position in Ora...
# 248  Wealthquest Corp increased its holdings in sha...
# 249  Wealthquest Corp trimmed its stake in Walgreen...
#
#                                                   link  \
# 0    https://www.americanbankingnews.com/2022/06/16...
# 1    https://www.americanbankingnews.com/2022/06/16...
# 2    https://www.americanbankingnews.com/2022/06/16...
# 3    https://www.americanbankingnews.com/2022/06/16...
# 4    https://www.americanbankingnews.com/2022/06/16...
# ..                                                 ...
# 245  https://www.americanbankingnews.com/2022/06/16...
# 246  https://www.americanbankingnews.com/2022/06/16...
# 247  https://www.americanbankingnews.com/2022/06/16...
# 248  https://www.americanbankingnews.com/2022/06/16...
# 249  https://www.americanbankingnews.com/2022/06/16...
#
#                              pubDate     creator     category
# 0    Thu, 16 Jun 2022 15:28:42 +0000  ABMN Staff  Market News
# 1    Thu, 16 Jun 2022 15:28:42 +0000  ABMN Staff  Market News
# 2    Thu, 16 Jun 2022 15:26:49 +0000  ABMN Staff  Market News
# 3    Thu, 16 Jun 2022 15:26:49 +0000  ABMN Staff  Market News
# 4    Thu, 16 Jun 2022 15:26:49 +0000  ABMN Staff  Market News
# ..                               ...         ...          ...
# 245  Thu, 16 Jun 2022 12:14:44 +0000  ABMN Staff  Market News
# 246  Thu, 16 Jun 2022 12:14:44 +0000  ABMN Staff  Market News
# 247  Thu, 16 Jun 2022 12:14:44 +0000  ABMN Staff  Market News
# 248  Thu, 16 Jun 2022 12:14:44 +0000  ABMN Staff  Market News
# 249  Thu, 16 Jun 2022 12:14:44 +0000  ABMN Staff  Market News
#
# [250 rows x 6 columns]

# %%
path = "/Users/R_files/rssBOF.csv"
new_df.to_csv(path)

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:dasnadas@localhost:5432')
new_df.to_sql('bofa1',engine)

# %%
session = boto3.Session(
    aws_access_key_id='your access key from aws',
    aws_secret_access_key='your secret key from aws',
)
s3 = session.resource('s3')
# Filename - File to upload
# Bucket - Bucket to upload to (the top level directory under AWS S3)
# Key - S3 object name (can contain subdirectories). If not specified then file_name is used
s3.meta.client.upload_file(Filename='/Users/R_files/rssBOF.csv', Bucket='mzfolder', Key='/Users/R_files/rssBOF.csv')

# %%
# access_key = '--- your access key from aws---'
# access_secret = '---your secret key from awws---'
# bucket_name = '--your foldeer name---'

# # client_s3 = boto3.client(
# #     's3',
# #     aws_access_key_id=access_key,
# #     aws_secret_access_key=access_secret
# # )

# %%
# client_s3

# %%
# def upload_file(file_name, bucket, object_name = None):
#     if object_name is None:
#         object_name = os.path.basename("rssBOF.csv")
#     s3_client = boto3.client('s3')
#     try:
#         response = s3_client.upload(file_name, bucket, object_name)
#     except ClientError as e:
#         logging.error(e)
#         return False
#     return True
# s3 = boto3.client('s3')
# with open("rssBOF.csv", "rb") as f:
#     s3.upload_fileobj(f, "mzfolder", f)
