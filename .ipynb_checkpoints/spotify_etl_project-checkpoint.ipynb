# %%
# import json
# import pandas as pd
from bs4 import BeautifulSoup

# %%
with open('/Users/mihirzala/Documents/response.json', 'r') as f:
    data = json.load(f)

# %%
print(data)
# Out:
# {'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw/albums?offset=0&limit=50&include_groups=album,single,compilation,appears_on&market=IN', 'items': [{'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'}, 'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw', 'id': '4YRxDV8wJFPHPTeXepOstw', 'name': 'Arijit Singh', 'type': 'artist', 'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/7vMWh9urOORyyFjwV4Drs4'}, 'href': 'https://api.spotify.com/v1/albums/7vMWh9urOORyyFjwV4Drs4', 'id': '7vMWh9urOORyyFjwV4Drs4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273156f9ab02be895a9be3de100', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02156f9ab02be895a9be3de100', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851156f9ab02be895a9b
# ...

# %%
new_data = json.loads(current_data)

# %%
new_data[0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#    'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#    'id': '4YRxDV8wJFPHPTeXepOstw',
#    'name': 'Arijit Singh',
#    'type': 'artist',
#    'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/7vMWh9urOORyyFjwV4Drs4'},
#  'href': 'https://api.spotify.com/v1/albums/7vMWh9urOORyyFjwV4Drs4',
#  'id': '7vMWh9urOORyyFjwV4Drs4',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273156f9ab02be895a9be3de100',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02156f9ab02be895a9be3de100',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851156f9ab02be895a9be3de100',
#    'width': 64}],
#  'name': 'Arijit Singh - India Tour Hits',
# ...

# %%
df = pd.json_normalize(new_data)

# %%
df
# Out:
#    album_group album_type                                            artists  \
# 0        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 1        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 2        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 3        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 4        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 5        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 6        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 7        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 8        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 9        album      album  [{'external_urls': {'spotify': 'https://open.s...
# 10       album      album  [{'external_urls': {'spotify': 'https://open.s...
# ...
